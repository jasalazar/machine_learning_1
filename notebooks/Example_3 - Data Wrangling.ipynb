# %%
import pandas as pd

# %%
data = pd.read_csv( "../datasets/customer-churn-model/Customer Churn Model.txt" )

# %%
data.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge   ...    Eve Calls  \
# 0             25     265.1        110       45.07   ...           99
# 1             26     161.6        123       27.47   ...          103
# 2              0     243.4        114       41.38   ...          110
# 3              0     299.4         71       50.90   ...           88
# 4              0     166.7        113       28.34   ...          122
#
#    Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# ...

# %% [markdown]
# # Creating a data subset

# %%
account_length = data[ "Account Length" ] #By selecting one column only, an object of type series is created
account_length.head()
# Out:
# 0    128
# 1    107
# 2    137
# 3     84
# 4     75
# Name: Account Length, dtype: int64

# %%
subset = data[[ "Account Length", "Phone", "Eve Charge", "Day Calls" ]] #Creating a subset out of the dataset. By selecting many columns, a dataframe is created
subset.head()
# Out:
#    Account Length     Phone  Eve Charge  Day Calls
# 0             128  382-4657       16.78        110
# 1             107  371-7191       16.62        123
# 2             137  358-1921       10.30        114
# 3              84  375-9999        5.26         71
# 4              75  330-6626       12.61        113

# %%
desired_cols = [ "Account Length", "Phone", "Eve Charge", "Night Calls" ]
subset = data[ desired_cols ]
subset.head()
# Out:
#    Account Length     Phone  Eve Charge  Night Calls
# 0             128  382-4657       16.78           91
# 1             107  371-7191       16.62          103
# 2             137  358-1921       10.30          104
# 3              84  375-9999        5.26           89
# 4              75  330-6626       12.61          121

# %%
all_cols_list = data.columns.values.tolist()
all_cols_list
# Out:
# ['State',
#  'Account Length',
#  'Area Code',
#  'Phone',
#  "Int'l Plan",
#  'VMail Plan',
#  'VMail Message',
#  'Day Mins',
#  'Day Calls',
#  'Day Charge',
#  'Eve Mins',
#  'Eve Calls',
#  'Eve Charge',
#  'Night Mins',
#  'Night Calls',
#  'Night Charge',
#  'Intl Mins',
#  'Intl Calls',
#  'Intl Charge',
#  'CustServ Calls',
#  'Churn?']

# %%
sublist = [ x for x in all_cols_list if x not in desired_cols ] #Sublist of non-desired (or target) columns
sublist
# Out:
# ['State',
#  'Area Code',
#  "Int'l Plan",
#  'VMail Plan',
#  'VMail Message',
#  'Day Mins',
#  'Day Calls',
#  'Day Charge',
#  'Eve Mins',
#  'Eve Calls',
#  'Night Mins',
#  'Night Charge',
#  'Intl Mins',
#  'Intl Calls',
#  'Intl Charge',
#  'CustServ Calls',
#  'Churn?']

# %%
subset = data[ sublist ] #Creating another subset with the desired cols
subset.head( 10 )
# Out:
#   State  Area Code Int'l Plan VMail Plan  VMail Message  Day Mins  Day Calls  \
# 0    KS        415         no        yes             25     265.1        110
# 1    OH        415         no        yes             26     161.6        123
# 2    NJ        415         no         no              0     243.4        114
# 3    OH        408        yes         no              0     299.4         71
# 4    OK        415        yes         no              0     166.7        113
# 5    AL        510        yes         no              0     223.4         98
# 6    MA        510         no        yes             24     218.2         88
# 7    MO        415        yes         no              0     157.0         79
# 8    LA        408         no         no              0     184.5         97
# 9    WV        415        yes        yes             37     258.6         84
#
#    Day Charge  Eve Mins  Eve Calls  Night Mins  Night Charge  Intl Mins  \
# ...

# %%
subset[:8] #Subset of the first 8 rows
# Out:
#   State  Area Code Int'l Plan VMail Plan  VMail Message  Day Mins  Day Calls  \
# 0    KS        415         no        yes             25     265.1        110
# 1    OH        415         no        yes             26     161.6        123
# 2    NJ        415         no         no              0     243.4        114
# 3    OH        408        yes         no              0     299.4         71
# 4    OK        415        yes         no              0     166.7        113
# 5    AL        510        yes         no              0     223.4         98
# 6    MA        510         no        yes             24     218.2         88
# 7    MO        415        yes         no              0     157.0         79
#
#    Day Charge  Eve Mins  Eve Calls  Night Mins  Night Charge  Intl Mins  \
# 0       45.07     197.4         99       244.7         11.01       10.0
# 1       27.47     195.5        103       254.4         11.45       13.7
# ...

# %%
data1 = data[ data["Day Mins"]>300 ] #Subset that complies with the condition
data1
# Out:
#      State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 15      NY             161        415  351-7269         no         no
# 76      DC              82        415  374-5353         no         no
# 156     OH              83        415  370-9116         no         no
# 197     TX             208        510  378-3625         no         no
# 230     MD              93        408  360-3324        yes         no
# 289     OK              89        510  352-6976         no         no
# 365     CO             154        415  343-5709         no         no
# 534     LA              67        510  373-6784         no         no
# 575     SD             114        415  351-7369         no        yes
# 605     MO             112        415  373-2053         no         no
# 688     MN              13        510  338-7120         no        yes
# 732     IN              48        510  342-6696         no         no
# ...

# %% [markdown]
# ## Users from Ohio

# %%
data2 = data[ data["State"] == "OH" ]
data2
# Out:
#      State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 1       OH             107        415  371-7191         no        yes
# 3       OH              84        408  375-9999        yes         no
# 152     OH              65        408  336-7600         no         no
# 156     OH              83        415  370-9116         no         no
# 231     OH              63        415  410-3719        yes        yes
# 362     OH              39        415  421-9752         no        yes
# 384     OH              84        408  336-9390         no         no
# 404     OH              73        415  338-4065         no         no
# 437     OH             100        510  385-8997         no         no
# 454     OH              97        408  405-6189         no         no
# 462     OH             144        415  392-3813         no        yes
# 506     OH             136        415  407-2248         no        yes
# ...

# %%
data3 = data[ (data["State"] == "OH") & (data["Day Mins"] > 300) ]
data3
# Out:
#      State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 156     OH              83        415  370-9116         no         no
# 2594    OH             115        510  348-1163        yes         no
#
#       VMail Message  Day Mins  Day Calls  Day Charge   ...    Eve Calls  \
# 156               0     337.4        120       57.36   ...          116
# 2594              0     345.3         81       58.70   ...          106
#
#       Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  \
# 156        19.33       153.9          114          6.93       15.8
# 2594       17.29       217.5          107          9.79       11.8
#
#       Intl Calls  Intl Charge  CustServ Calls  Churn?
# 156            7         4.27               0   True.
# 2594           8         3.19               1   True.
#
# [2 rows x 21 columns]
